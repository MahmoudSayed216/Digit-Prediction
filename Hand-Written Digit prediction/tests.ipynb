# %%
from utils.gaussian import *
import cv2
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot  as plt
digit = cv2.imread("../Hand Written Digits/HAND WRITTEN DIGITS/2.jpg")
original = digit[:, :, 1]
smooth = gaussian_blur(original)

# %%
plt.imshow(original.reshape(28, 28), cmap=mpl.cm.binary)

# %%
plt.imshow(smooth.reshape(28, 28), cmap=mpl.cm.binary)
